# %%
import numpy as np
import pandas as pd

# %%
data_path="D:\\Projects\\price_history\\data\\Delhi\\"

# %%
# for i in range(2014,2023):
#     print("dl_"+str(i)+"=pd.read_csv(data_path+'prices_delhi_"+str(i)+".csv')")

# %%
dl_2014=pd.read_csv(data_path+'prices_delhi_2014.csv')
dl_2015=pd.read_csv(data_path+'prices_delhi_2015.csv')
dl_2016=pd.read_csv(data_path+'prices_delhi_2016.csv')
dl_2017=pd.read_csv(data_path+'prices_delhi_2017.csv')
dl_2018=pd.read_csv(data_path+'prices_delhi_2018.csv')
dl_2019=pd.read_csv(data_path+'prices_delhi_2019.csv')
dl_2022=pd.read_csv(data_path+'prices_delhi_2022.csv')

# %%
df=pd.concat([dl_2014,dl_2015,dl_2016,dl_2017,dl_2018,dl_2019,dl_2022])

# %%
df.describe()
# Out:
#                  1            2            3            4            5  \
# count  2886.000000  2486.000000  2886.000000  2886.000000  2886.000000
# mean     32.064103    21.197908    24.022869    76.323285   102.139640
# std       2.346807     2.197733     2.248396    16.622273    22.416792
# min      26.000000    18.000000    20.000000    46.000000    72.000000
# 25%      30.000000    19.000000    22.000000    71.000000    84.000000
# 50%      32.000000    20.000000    24.000000    73.000000    97.000000
# 75%      34.000000    23.000000    26.000000    79.000000   110.000000
# max      36.000000    26.000000    29.000000   144.000000   182.000000
#
#                  6            7            8            9           10  ...  \
# count  2886.000000  2886.000000  2885.000000  2886.000000  2886.000000  ...
# mean    105.331601    95.295565    81.645754    38.554401    42.564796  ...
# std      23.008804     9.631960     9.597625     3.235042     3.878813  ...
# ...

# %%
df.to_csv("D:\\Projects\\price_history\\data\\"+"prices_DELHI.csv")
