# %%
#!python --version
#!pip install darts
# Out:
# Python 3.10.4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from darts import TimeSeries
from darts.utils.missing_values import missing_values_ratio ,fill_missing_values

# %%
df=pd.read_csv('pricesChennai.csv')
#df.head()
#df.describe()
#df.shape

# %%
def create_imputed_timeseries(c):
    #c is the column that we plan to forecast
    new_df=df[[c,'23']]
    
    #converting to proper data time object
    new_df['day'] =  pd.to_datetime(new_df['23'], format='%d/%m/%Y')
    new_df.drop('23', axis=1, inplace=True)
    new_df.rename(columns = {c:'price'}, inplace = True)
    
    #create Time series object
    commodity=TimeSeries.from_dataframe(new_df,time_col='day',value_cols='price')
    
    #impute missing values
    commodity_imputed=fill_missing_values(commodity)
    return commodity,commodity_imputed

# %%
df.plot.line(x=23,y=[11,12,13,14,15,16],figsize=(20,20))
# Out:
# <AxesSubplot:xlabel='23'>

# %%
df.plot.line(x=23,y=[14],figsize=(20,20))
# Out:
# <AxesSubplot:xlabel='23'>

# %%
commodity_orig,commodity_cleaned=create_imputed_timeseries('11')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8220\55082371.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['day'] =  pd.to_datetime(new_df['23'], format='%d/%m/%Y')
# C:\Users\hp\AppData\Local\Temp\ipykernel_8220\55082371.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop('23', axis=1, inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_8220\55082371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns = {c:'price'}, inplace = True)

# %%
commodity_cleaned.plot()
commodity_orig.plot()

# %%
train, val = commodity_cleaned.split_before(0.75)
train.plot(label="training")
val.plot(label="validation")

# %%
from darts.utils.statistics import plot_acf, check_seasonality

plot_acf(train, m=12, alpha=0.05)
#absolutely no seasonality - proved as there is no peak after the 0 point. 
#It seems to be continuously dectrasing from that

# %%
from darts.models import  NBEATSModel
from darts.metrics import mape
import numpy as np

# %%
#DEFINING THE MODEL 
NBEATS_MODEL = NBEATSModel(input_chunk_length = 30, output_chunk_length =7 , n_epochs=100, random_state=0)
#give the .fit method the training series and the validation series
NBEATS_MODEL.fit(train,val_series = val, verbose=True)
#get the predictions for the next TESTING DATA, 6 MONTH = 360 DAYS 
pred = NBEATS_MODEL.predict(n=720, series = train  )
#get the error using the mape
pred_error = mape(val[:720],pred)
#error_follower = mape(val_follower[:36],pred_follower)
print("this is the error for the price:",pred_error )
# Out:
# 2022-08-11 13:26:03 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 2312 samples.
# 2022-08-11 13:26:03 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 64-bits; casting model to float64.
# 2022-08-11 13:26:03 pytorch_lightning.utilities.rank_zero INFO: GPU available: False, used: False
# 2022-08-11 13:26:03 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-08-11 13:26:03 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-08-11 13:26:03 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-08-11 13:26:04 pytorch_lightning.callbacks.model_summary INFO:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.2 M
# ---------------------------------------------------
# 6.2 M     Trainable params
# 1.5 K     Non-trainable params
# 6.2 M     Total params
# 49.945    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [33], in <cell line: 4>()
#       2 NBEATS_MODEL = NBEATSModel(input_chunk_length = 30, output_chunk_length =7 , n_epochs=100, random_state=0)
#       3 #give the .fit method the training series and the validation series
# ----> 4 NBEATS_MODEL.fit(train,val_series = val, verbose=True)
#       5 #get the predictions for the next TESTING DATA, 6 MONTH = 360 DAYS
#       6 pred = NBEATS_MODEL.predict(n=720, series = train  )
#
# File D:\anaconda3\envs\price_history\lib\site-packages\darts\utils\torch.py:112, in random_method.<locals>.decorator(self, *args, **kwargs)
#     110 with fork_rng():
#     111     manual_seed(self._random_instance.randint(0, high=MAX_TORCH_SEED_VALUE))
# --> 112     return decorated(self, *args, **kwargs)
#
# File D:\anaconda3\envs\price_history\lib\site-packages\darts\models\forecasting\torch_forecasting_model.py:771, in TorchForecastingModel.fit(self, series, past_covariates, future_covariates, val_series, val_past_covariates, val_future_covariates, trainer, verbose, epochs, max_samples_per_ts, num_loader_workers)
#     767     val_dataset = None
#     769 logger.info(f"Train dataset contains {len(train_dataset)} samples.")
# --> 771 return self.fit_from_dataset(
#     772     train_dataset, val_dataset, trainer, verbose, epochs, num_loader_workers
#     773 )
#
# File D:\anaconda3\envs\price_history\lib\site-packages\darts\utils\torch.py:112, in random_method.<locals>.decorator(self, *args, **kwargs)
#     110 with fork_rng():
#     111     manual_seed(self._random_instance.randint(0, high=MAX_TORCH_SEED_VALUE))
# --> 112     return decorated(self, *args, **kwargs)
#
# File D:\anaconda3\envs\price_history\lib\site-packages\darts\models\forecasting\torch_forecasting_model.py:913, in TorchForecastingModel.fit_from_dataset(self, train_dataset, val_dataset, trainer, verbose, epochs, num_loader_workers)
#     904     logger.warn(
#     905         "Attempting to retrain the model without resuming from a checkpoint. This is currently "
#     906         "discouraged. Consider setting `save_checkpoints` to `True` and specifying `model_name` at model "
#    (...)
#     909         "`new_epochs` is the sum of (epochs already trained + some additional epochs)."
#     910     )
#     912 # Train model
# --> 913 self._train(train_loader, val_loader)
#     914 return self
#
# File D:\anaconda3\envs\price_history\lib\site-packages\darts\models\forecasting\torch_forecasting_model.py:935, in TorchForecastingModel._train(self, train_loader, val_loader)
#     932 ckpt_path = self.load_ckpt_path
#     933 self.load_ckpt_path = None
# --> 935 self.trainer.fit(
#     936     self.model,
#     937     train_dataloaders=train_loader,
#     938     val_dataloaders=val_loader,
#     939     ckpt_path=ckpt_path,
#     940 )
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\trainer\trainer.py:700, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     681 r"""
#     682 Runs the full optimization routine.
#     683
#    (...)
#     697     datamodule: An instance of :class:`~pytorch_lightning.core.datamodule.LightningDataModule`.
#     698 """
#     699 self.strategy.model = model
# --> 700 self._call_and_handle_interrupt(
#     701     self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     702 )
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\trainer\trainer.py:654, in Trainer._call_and_handle_interrupt(self, trainer_fn, *args, **kwargs)
#     652         return self.strategy.launcher.launch(trainer_fn, *args, trainer=self, **kwargs)
#     653     else:
# --> 654         return trainer_fn(*args, **kwargs)
#     655 # TODO(awaelchli): Unify both exceptions below, where `KeyboardError` doesn't re-raise
#     656 except KeyboardInterrupt as exception:
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\trainer\trainer.py:741, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     737 ckpt_path = ckpt_path or self.resume_from_checkpoint
#     738 self._ckpt_path = self.__set_ckpt_path(
#     739     ckpt_path, model_provided=True, model_connected=self.lightning_module is not None
#     740 )
# --> 741 results = self._run(model, ckpt_path=self.ckpt_path)
#     743 assert self.state.stopped
#     744 self.training = False
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\trainer\trainer.py:1166, in Trainer._run(self, model, ckpt_path)
#    1162 self._checkpoint_connector.restore_training_state()
#    1164 self._checkpoint_connector.resume_end()
# -> 1166 results = self._run_stage()
#    1168 log.detail(f"{self.__class__.__name__}: trainer tearing down")
#    1169 self._teardown()
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\trainer\trainer.py:1252, in Trainer._run_stage(self)
#    1250 if self.predicting:
#    1251     return self._run_predict()
# -> 1252 return self._run_train()
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\trainer\trainer.py:1274, in Trainer._run_train(self)
#    1271 self._pre_training_routine()
#    1273 with isolate_rng():
# -> 1274     self._run_sanity_check()
#    1276 # enable train mode
#    1277 self.model.train()
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\trainer\trainer.py:1342, in Trainer._run_sanity_check(self)
#    1340 # run eval step
#    1341 with torch.no_grad():
# -> 1342     val_loop.run()
#    1344 self._call_callback_hooks("on_sanity_check_end")
#    1346 # reset logger connector
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\loops\loop.py:200, in Loop.run(self, *args, **kwargs)
#     198 try:
#     199     self.on_advance_start(*args, **kwargs)
# --> 200     self.advance(*args, **kwargs)
#     201     self.on_advance_end()
#     202     self._restarting = False
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\loops\dataloader\evaluation_loop.py:155, in EvaluationLoop.advance(self, *args, **kwargs)
#     153 if self.num_dataloaders > 1:
#     154     kwargs["dataloader_idx"] = dataloader_idx
# --> 155 dl_outputs = self.epoch_loop.run(self._data_fetcher, dl_max_batches, kwargs)
#     157 # store batch level output per dataloader
#     158 self._outputs.append(dl_outputs)
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\loops\loop.py:200, in Loop.run(self, *args, **kwargs)
#     198 try:
#     199     self.on_advance_start(*args, **kwargs)
# --> 200     self.advance(*args, **kwargs)
#     201     self.on_advance_end()
#     202     self._restarting = False
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\loops\epoch\evaluation_epoch_loop.py:127, in EvaluationEpochLoop.advance(self, data_fetcher, dl_max_batches, kwargs)
#     125 if not isinstance(data_fetcher, DataLoaderIterDataFetcher):
#     126     batch_idx = self.batch_progress.current.ready
# --> 127     batch = next(data_fetcher)
#     128 else:
#     129     batch_idx, batch = next(data_fetcher)
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\utilities\fetching.py:185, in AbstractDataFetcher.__next__(self)
#     184 def __next__(self) -> Any:
# --> 185     return self.fetching_function()
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\utilities\fetching.py:264, in DataFetcher.fetching_function(self)
#     261 elif not self.done:
#     262     # this will run only when no pre-fetching was done.
#     263     try:
# --> 264         self._fetch_next_batch(self.dataloader_iter)
#     265         # consume the batch we just fetched
#     266         batch = self.batches.pop(0)
#
# File D:\anaconda3\envs\price_history\lib\site-packages\pytorch_lightning\utilities\fetching.py:278, in DataFetcher._fetch_next_batch(self, iterator)
#     276 def _fetch_next_batch(self, iterator: Iterator) -> None:
#     277     start_output = self.on_fetch_start()
# --> 278     batch = next(iterator)
#     279     self.fetched += 1
#     280     if not self.prefetch_batches and self._has_len:
#     281         # when we don't prefetch but the dataloader is sized, we use the length for `done`
#
# File D:\anaconda3\envs\price_history\lib\site-packages\torch\utils\data\dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# File D:\anaconda3\envs\price_history\lib\site-packages\torch\utils\data\dataloader.py:721, in _SingleProcessDataLoaderIter._next_data(self)
#     719 def _next_data(self):
#     720     index = self._next_index()  # may raise StopIteration
# --> 721     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722     if self._pin_memory:
#     723         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File D:\anaconda3\envs\price_history\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50 else:
#      51     data = self.dataset[possibly_batched_index]
# ---> 52 return self.collate_fn(data)
#
# File D:\anaconda3\envs\price_history\lib\site-packages\darts\models\forecasting\torch_forecasting_model.py:1262, in TorchForecastingModel._batch_collate_fn(batch)
#    1259 elem = first_sample[i]
#    1260 if isinstance(elem, np.ndarray):
#    1261     aggregated.append(
# -> 1262         torch.from_numpy(np.stack([sample[i] for sample in batch], axis=0))
#    1263     )
#    1264 elif elem is None:
#    1265     aggregated.append(None)
#
# RuntimeError: Numpy is not available

# %%
# #rice Prices
# new_df=df[['1','23']]
# #converting to proper data time object
# new_df['Day'] =  pd.to_datetime(new_df['23'], format='%d/%m/%Y')
# new_df.drop('23', axis=1, inplace=True)
# new_df.rename(columns = {'1':'Price'}, inplace = True)
# #new_df.dtypes
# #new_df.head()
# rice=TimeSeries.from_dataframe(new_df,time_col='Day',value_cols='Price')
# rice.plot()

# %%
# percentage of missing values in the dataset
missing_values_ratio(commodity_orig)*100
# Out:
# 12.51596424010217

# %%
#imputing the missing values using the pandas interpolate function in the backend.
# the data is here imputed in a linear interpolation.
# See more information on here:
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.interpolate.html
#rice_imputed=fill_missing_values(rice)
#rice_imputed.plot()

# %%
#new_df['Price'].plot(figsize=(20, 20))

# %%
# Watch the imputed chart in large detail (large size plot of the same thing)

# rice_imputed_df=rice_imputed.pd_dataframe()
# rice_imputed_df.plot(figsize=(20, 20))

# %%
# rice_imputed.plot()
# rice.plot()

# %%
commodity_list='''Rice#1
Wheat#2
Atta (Wheat)#3
Gram Dal#4
Tur/Arhar Dal#5
Urad Dal	#6
Moong Dal#7
Masoor Dal#8
Sugar#9
Milk @#10
Groundnut Oil (Packed)#11
Mustard Oil (Packed)#12
Vanaspati (Packed)#13
Soya Oil (Packed)#14
Sunflower Oil (Packed)#15
Palm Oil (Packed)#16
Gur#17
Tea Loose#18
Salt Pack (Iodised)#19
Potato#20
Onion#21
Tomato#22'''
# Out:
# 'Rice#1\nWheat#2\nAtta (Wheat)#3\nGram Dal#4\nTur/Arhar Dal#5\nUrad Dal\t#6\nMoong Dal#7\nMasoor Dal#8\nSugar#9\nMilk @#10\nGroundnut Oil (Packed)#11\nMustard Oil (Packed)#12\nVanaspati (Packed)#13\nSoya Oil (Packed)#14\nSunflower Oil (Packed)#15\nPalm Oil (Packed)#16\nGur#17\nTea Loose#18\nSalt Pack (Iodised)#19\nPotato#20\nOnion#21\nTomato#22'

# %% [markdown]
# # Fuel Prices EDA for chennai Dataset (from the fuel scrapped data)

# %%
df1=pd.read_csv('Chennaipetrol.csv')
df1.head()
# Out:
#       city        date   rate
# 0  Chennai  2014-01-04  75.71
# 1  Chennai  2014-03-01  76.48
# 2  Chennai  2014-04-01  75.49
# 3  Chennai  2014-04-16  74.60
# 4  Chennai  2014-06-07  74.71

# %%
#df1['rate'].plot()
df1['date'] =  pd.to_datetime(df1['date'], format='%Y-%m-%d')
df1.plot.line(x='date',y='rate',figsize=(20,20))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df1['date']
# Out:
# 0      2014-01-04
# 1      2014-03-01
# 2      2014-04-01
# 3      2014-04-16
# 4      2014-06-07
#           ...
# 1143   2022-08-07
# 1144   2022-08-08
# 1145   2022-08-09
# 1146   2022-08-10
# 1147   2022-08-11
# Name: date, Length: 1148, dtype: datetime64[ns]

# %%
df2=commodity_cleaned.pd_dataframe()

# %%
df2['date'] = df2.index

# %%
df2.head()#commodity price
# Out:
# component   price       date
# day
# 2014-01-01  105.0 2014-01-01
# 2014-01-02  105.0 2014-01-02
# 2014-01-03  105.0 2014-01-03
# 2014-01-04  105.0 2014-01-04
# 2014-01-05  105.0 2014-01-05

# %%
df1.head()#petrol price
# Out:
#       city       date   rate
# 0  Chennai 2014-01-04  75.71
# 1  Chennai 2014-03-01  76.48
# 2  Chennai 2014-04-01  75.49
# 3  Chennai 2014-04-16  74.60
# 4  Chennai 2014-06-07  74.71

# %%
df3=df2.merge(df1, how='left', on='date')
df3.head()
# Out:
#    price       date     city   rate
# 0  105.0 2014-01-01      NaN    NaN
# 1  105.0 2014-01-02      NaN    NaN
# 2  105.0 2014-01-03      NaN    NaN
# 3  105.0 2014-01-04  Chennai  75.71
# 4  105.0 2014-01-05      NaN    NaN

# %%
df3_cut=df3[df3['date']>='2017-06-26']
df3_cut.head()
# Out:
#       price       date     city   rate
# 1273  139.0 2017-06-26  Chennai  66.03
# 1274  139.0 2017-06-27  Chennai  65.89
# 1275  139.0 2017-06-28  Chennai  65.94
# 1276  138.0 2017-06-29  Chennai  65.90
# 1277  138.0 2017-06-30  Chennai  65.78

# %%
new_df1.isnull().sum()
# Out:
# rate    800
# day       0
# dtype: int64

# %%
new_df1.head()
# Out:
#        rate        day
# 1273  66.03 2017-06-26
# 1274  65.89 2017-06-27
# 1275  65.94 2017-06-28
# 1276  65.90 2017-06-29
# 1277  65.78 2017-06-30

# %%
new_df1.head()
# Out:
#       index   rate       date
# time
# 0      1273  66.03 2017-06-26
# 1      1274  65.89 2017-06-27
# 2      1275  65.94 2017-06-28
# 3      1276  65.90 2017-06-29
# 4      1277  65.78 2017-06-30

# %%
new_df1.to_csv('merged_new-df1.csv')

# %%
df1[df1['date']=='11-1-2019']
# Out:
#         city       date   rate
# 555  Chennai 2019-11-01  75.78
# 556  Chennai 2019-11-01  75.66

# %%
df1.iloc[405]
# Out:
# city                Chennai
# date    2019-01-14 00:00:00
# rate                  72.83
# Name: 405, dtype: object

# %%
new_df1=df3_cut[['rate','date']]
#new_df1.rename(columns = {'date':'day'}, inplace = True)
new_df1=new_df1.reset_index()
# # # #create Time series object
petrol_chennai=TimeSeries.from_dataframe(new_df1,value_cols='rate',time_col='date')

# #impute missing values
petrol_chennai_imputed=fill_missing_values(petrol_chennai)
# Out:
# 2022-08-12 00:17:29 darts.timeseries ERROR: ValueError: The time index of the provided DataArray is missing the freq attribute, and the frequency could not be directly inferred. This probably comes from inconsistent date frequencies with missing dates. If you know the actual frequency, try setting `fill_missing_dates=True, freq=actual_frequency`. If not, try setting `fill_missing_dates=True, freq=None` to see if a frequency can be inferred.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [194], in <cell line: 5>()
#       3 new_df1=new_df1.reset_index()
#       4 # # # #create Time series object
# ----> 5 petrol_chennai=TimeSeries.from_dataframe(new_df1,value_cols='rate',time_col='date')
#       7 # #impute missing values
#       8 petrol_chennai_imputed=fill_missing_values(petrol_chennai)
#
# File D:\anaconda3\envs\price_history\lib\site-packages\darts\timeseries.py:663, in TimeSeries.from_dataframe(cls, df, time_col, value_cols, fill_missing_dates, freq, fillna_value, static_covariates, hierarchy)
#     654     time_index.name = time_col if time_col else DIMS[0]
#     656 xa = xr.DataArray(
#     657     series_df.values[:, :, np.newaxis],
#     658     dims=(time_index.name,) + DIMS[-2:],
#     659     coords={time_index.name: time_index, DIMS[1]: series_df.columns},
#     660     attrs={STATIC_COV_TAG: static_covariates, HIERARCHY_TAG: hierarchy},
#     661 )
# --> 663 return cls.from_xarray(
#     664     xa=xa,
#     665     fill_missing_dates=fill_missing_dates,
#     666     freq=freq,
#     667     fillna_value=fillna_value,
#     668 )
#
# File D:\anaconda3\envs\price_history\lib\site-packages\darts\timeseries.py:409, in TimeSeries.from_xarray(cls, xa, fill_missing_dates, freq, fillna_value)
#     405 # We cast the array to float
#     406 if np.issubdtype(xa_.values.dtype, np.float32) or np.issubdtype(
#     407     xa_.values.dtype, np.float64
#     408 ):
# --> 409     return cls(xa_)
#     410 else:
#     411     return cls(xa_.astype(np.float64))
#
# File D:\anaconda3\envs\price_history\lib\site-packages\darts\timeseries.py:172, in TimeSeries.__init__(self, xa)
#     164 freq_tmp = xa.get_index(
#     165     self._time_dim
#     166 ).freq  # store original freq (see bug of sortby() above).
#     167 self._freq: pd.DateOffset = (
#     168     freq_tmp
#     169     if freq_tmp is not None
#     170     else to_offset(self._xa.get_index(self._time_dim).inferred_freq)
#     171 )
# --> 172 raise_if(
#     173     self._freq is None,
#     174     "The time index of the provided DataArray is missing the freq attribute, and the frequency could "
#     175     "not be directly inferred. "
#     176     "This probably comes from inconsistent date frequencies with missing dates. "
#     177     "If you know the actual frequency, try setting `fill_missing_dates=True, freq=actual_frequency`. "
#     178     "If not, try setting `fill_missing_dates=True, freq=None` to see if a frequency can be inferred.",
#     179     logger,
#     180 )
#     182 self._freq_str: str = self._freq.freqstr
#     184 # reset freq inside the xarray index (see bug of sortby() above).
#
# File D:\anaconda3\envs\price_history\lib\site-packages\darts\logging.py:106, in raise_if(condition, message, logger)
#      83 def raise_if(
#      84     condition: bool,
#      85     message: str = "",
#      86     logger: logging.Logger = get_logger("main_logger"),
#      87 ):
#      88     """
#      89     Checks provided boolean condition and raises a ValueError if it evaluates to True.
#      90     It logs the error to the provided logger before raising it.
#    (...)
#     104         if `condition` is satisfied
#     105     """
# --> 106     raise_if_not(not condition, message, logger)
#
# File D:\anaconda3\envs\price_history\lib\site-packages\darts\logging.py:80, in raise_if_not(condition, message, logger)
#      78 if not condition:
#      79     logger.error("ValueError: " + message)
# ---> 80     raise ValueError(message)
#
# ValueError: The time index of the provided DataArray is missing the freq attribute, and the frequency could not be directly inferred. This probably comes from inconsistent date frequencies with missing dates. If you know the actual frequency, try setting `fill_missing_dates=True, freq=actual_frequency`. If not, try setting `fill_missing_dates=True, freq=None` to see if a frequency can be inferred.

# %%
df3.plot.line(x='date',y=['rate'],figsize=(20,20))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df2.dtypes
# Out:
# component
# price           float64
# date     datetime64[ns]
# dtype: object

# %%
petrol_chennai_imputed.plot()
commodity_cleaned.plot()

# %%
petrol_chennai_imputed.plot()

# %%
df3.dtypes
# Out:
# price           float64
# date     datetime64[ns]
# city             object
# rate            float64
# dtype: object

# %%
df1.dtypes
# Out:
# city            object
# date    datetime64[ns]
# rate           float64
# dtype: object
